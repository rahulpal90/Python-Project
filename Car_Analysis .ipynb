# %%
# Importing Library 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy

# %%
car = pd.read_csv(r"D:\Data set\cardata.csv")
car
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 0        Dealer       Manual      0
# 1        Dealer       Manual      0
# ...

# %%
# to knowing the shape of data means how many rows and Columns are in data 
car.shape
# Out:
# (301, 9)

# %%
# info of data 
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_Name       301 non-null    object
#  1   Year           301 non-null    int64
#  2   Selling_Price  301 non-null    float64
#  3   Present_Price  301 non-null    float64
#  4   Kms_Driven     301 non-null    int64
#  5   Fuel_Type      301 non-null    object
#  6   Seller_Type    301 non-null    object
#  7   Transmission   301 non-null    object
#  8   Owner          301 non-null    int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 21.3+ KB

# %%
car.describe()
# Out:
#               Year  Selling_Price  Present_Price     Kms_Driven       Owner
# count   301.000000     301.000000     301.000000     301.000000  301.000000
# mean   2013.627907       4.661296       7.628472   36947.205980    0.043189
# std       2.891554       5.082812       8.644115   38886.883882    0.247915
# min    2003.000000       0.100000       0.320000     500.000000    0.000000
# 25%    2012.000000       0.900000       1.200000   15000.000000    0.000000
# 50%    2014.000000       3.600000       6.400000   32000.000000    0.000000
# 75%    2016.000000       6.000000       9.900000   48767.000000    0.000000
# max    2018.000000      35.000000      92.600000  500000.000000    3.000000

# %%
#find null values in data set.
car.isnull() .sum()
# Out:
# Car_Name         0
# Year             0
# Selling_Price    0
# Present_Price    0
# Kms_Driven       0
# Fuel_Type        0
# Seller_Type      0
# Transmission     0
# Owner            0
# dtype: int64

# %%
# Check what are the different  types of makes are there in our dataset and ,what is the count of each make it the data ?

car['Car_Name'].value_counts().head(10)
# Out:
# city             26
# corolla altis    16
# verna            14
# fortuner         11
# brio             10
# ciaz              9
# innova            9
# i20               9
# grand i10         8
# jazz              7
# Name: Car_Name, dtype: int64

# %%
# Car Name Wise bar plot
car['Car_Name'].value_counts().head(10).plot(kind='bar')
plt.title('Top 10 Car')
plt.show()

# %%
# Year  wise value count
car['Year'] .value_counts()
# Out:
# 2015    61
# 2016    50
# 2014    38
# 2017    35
# 2013    33
# 2012    23
# 2011    19
# 2010    15
# 2008     7
# 2009     6
# 2006     4
# 2005     4
# 2003     2
# 2007     2
# 2018     1
# 2004     1
# Name: Year, dtype: int64

# %%
# year Wise Bar Graph.
plt.figure(figsize = (10,4))
sns.countplot(x = "Year",data=car)
plt.title('Car Age')
plt.show()

# %%
car.head(1)
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0

# %%
# Use .unique() Function Known  Transmission. 
car['Transmission'].unique()
# Out:
# array(['Manual', 'Automatic'], dtype=object)

# %%
plt.figure(figsize = (10,4))
sns.countplot(x = "Transmission" ,data = car)
plt.title("Transmission Chart")
plt.show()

# %%
car.head(1)
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0

# %%
# Fuel type 
car['Fuel_Type'].unique()
# Out:
# array(['Petrol', 'Diesel', 'CNG'], dtype=object)

# %%
plt.figure(figsize = (10,4))
sns.countplot(x="Fuel_Type" , data = car)
plt.title("Fuel_Type")
plt.show()

# %%
# seller type
plt.figure(figsize= (10,4))
sns.countplot(x = "Seller_Type",data = car)
plt.title("Sellers")
plt.show()

# %%
car.head(1)
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0

# %%
# Selling price and prsent Price distribution 
plt.figure(figsize=(10,6))
sns.histplot(car['Selling_Price'] , kde = True , label = "Selling Price")
sns.histplot(car['Present_Price'] , kde = True , label = " Present Price")
plt.title('Selling price and prsent Price distribution')
plt.legend()
plt.show()

# %%
# distribution kilometers Driven

plt.figure(figsize= (10,6))
sns.histplot(car['Kms_Driven'],bins= 30 ,kde = True ,color = 'b')
plt.title('Distribution of Kilometers Driven')
plt.show()

# %%
# pair plot 
sns.pairplot(car)
plt.suptitle('Pairplot of Numerical Columns', y=1.02)
plt.show()

# %%
numerical_data = car.select_dtypes(include=['float64','int64'])
plt.figure(figsize=(10,6))
sns.heatmap(numerical_data.corr() ,annot = True)
plt.title('Correlection Heatmap')
plt.show()
